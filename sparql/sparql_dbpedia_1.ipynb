# %% [markdown]
# # Interrogation du point d'accès SPARQL de DBPedia (en anglais)
#
# Dans cet exemple, après avoir interrogé le point d'accès SPARQL de lDBPedia, on extrait des données ...
#
#
# On créer également un document CSV exportable et analysable avec d'autres outils (un tableur par ex.).

# %% [markdown]
# ## Importer les librairies à utiliser

# %%
from SPARQLWrapper import SPARQLWrapper, SPARQLWrapper2, JSON, TURTLE, XML, RDFXML
import pprint
import csv
# from bs4 import BeautifulSoup
import matplotlib.pyplot as plt

from collections import Counter
from operator import itemgetter
import pandas as pd
import sqlite3 as sql

# %%
## fonction générique permettant de transformer en liste les résultats d'une requête


def sparql_result_to_list (result, limit, *variables):
    
    i = 0
    result_l = []
    for l in result['results']['bindings']:
        if i < limit:
            l_line = []
            for v in variables[0]:
                l_line.append(l[v]['value'])
                        
        result_l.append(l_line)
        i += 1
        
    return result_l

# %% [markdown]
# ## Explorer Wikipedia / DBPedia
#
# DBPedia est une extraction de données semistructurées et structurées à partir des Infobox et du résumé des pages de Wikipedia.
#
# Les versions de DBPedia sont liées aux versions linguistiques de Wikipedia et dépendent de l'activité de 'chapitres' nationaux DBPedia. Il existe une communauté et version francophone.
#
# Nous explorerons ici la version anglaise qui est la plus riche mais les différentes versions sont connectées, et on peut profiter de ces versions.

# %% [markdown]
# ### Wikipedia: Les économistes, page "Economist"
#
# *  https://en.wikipedia.org/wiki/Economist
# *  https://en.wikipedia.org/wiki/Economics
#
#
# ### DBPedia : Economist
#
# *  https://dbpedia.org/page/Economist
# *  https://dbpedia.org/ontology/Economist
#
# *  https://dbpedia.org/page/Economics

# %% [markdown]
# ## DBPedia SPARQL Endpoint
#
# https://dbpedia.org/sparql
#
# Documentation : [SPARQL 1.1 Query Language](http://www.w3.org/TR/sparql11-query/)

# %% [markdown]
# ### Keynes dans DBPedia
#
# *  https://en.wikipedia.org/wiki/John_Maynard_Keynes
# *  https://dbpedia.org/page/John_Maynard_Keynes

# %% [raw]
# <!-- Extrait de l'info box de la page : https://en.wikipedia.org/wiki/John_Maynard_Keynes -->
# <table class="infobox biography vcard" style="width:22em">
#  <tbody>
#   <tr>
#     <th scope="row">Born</th>
#     <td>
#       <span style="display:none">(<span class="bday">1883-06-05</span>)</span>5 June 1883<br />
#       <div style="display:inline" class="birthplace">
#         <a href="/wiki/Cambridge" title="Cambridge">Cambridge</a>, <a href="/wiki/Cambridgeshire" title="Cambridgeshire">Cambridgeshire</a>, England</div>
#       </td>
#     </tr>
#     <tr>
#       <th scope="row">Alma&#160;mater</th>
#       <td>
#         <a href="/wiki/Eton_College" title="Eton College">Eton College</a>
#         <br />
#         <a href="/wiki/King%E2%80%99s_College,_Cambridge" class="mw-redirect" title="King’s College, Cambridge">King’s College, Cambridge</a>
#       </td>
#     </tr>
#     <tr>
#       <th scope="row">Political party</th>
#       <td class="org">
#         <a href="/wiki/Liberal_Party_(UK)" title="Liberal Party (UK)">Liberal</a>
#       </td>
#     </tr>
#   </tbody>
# </table>

# %%
sparql = SPARQLWrapper("https://dbpedia.org/sparql") ##, returnFormat=RDFXML)

# %%
q_keynes = """

PREFIX dbpedia: <http://dbpedia.org/resource/>
SELECT * WHERE {
dbpedia:John_Maynard_Keynes ?p ?o
}

"""

# %%
sparql.setQuery(q_keynes)
sparql.setReturnFormat(JSON)
rc = sparql.queryAndConvert()
# type(rc)

# %%
# Nombre de lignes du résultat
len(rc['results']['bindings'])
# Out:
# 937

# %%
# Inspecter les trois premières lignes
i = 0
for l in rc['results']['bindings']:
    if i < 3:
        print(l)
        i += 1
# Out:
# {'p': {'type': 'uri', 'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'}, 'o': {'type': 'uri', 'value': 'http://www.w3.org/2002/07/owl#Thing'}}
# {'p': {'type': 'uri', 'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'}, 'o': {'type': 'uri', 'value': 'http://xmlns.com/foaf/0.1/Person'}}
# {'p': {'type': 'uri', 'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'}, 'o': {'type': 'uri', 'value': 'http://dbpedia.org/ontology/Person'}}

# %%
variables = ('p', 'o')

# %%
r = [print(l) for l in sparql_result_to_list(rc, 1000, variables)]
# Out:
# ['http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 'http://www.w3.org/2002/07/owl#Thing']
# ['http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 'http://xmlns.com/foaf/0.1/Person']
# ['http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 'http://dbpedia.org/ontology/Person']
# ['http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 'http://schema.org/Person']
# ['http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 'http://dbpedia.org/class/yago/Object100002684']
# ['http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 'http://dbpedia.org/class/yago/Official110372373']
# ['http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 'http://dbpedia.org/class/yago/Organism100004475']
# ['http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 'http://dbpedia.org/class/yago/Peer109626238']
# ['http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 'http://dbpedia.org/class/yago/Person100007846']
# ['http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 'http://dbpedia.org/class/yago/Philanthropist110421956']
# ['http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 'http://dbpedia.org/class/yago/Philosopher110423589']
# ['http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 'http://dbpedia.org/class/yago/PhysicalEntity100001930']
# ['http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 'http://dbpedia.org/class/yago/PoliticalScientist110450161']
# ['http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 'http://dbpedia.org/class/yago/Politician110450303']
# ['http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 'http://dbpedia.org/class/yago/Possession100032613']
# ['http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 'http://dbpedia.org/class/yago/President110467179']
# ['http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 'http://dbpedia.org/class/yago/ProbabilityTheorist110477465']
# ['http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 'http://dbpedia.org/class/yago/Professional110480253']
# ['http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 'http://dbpedia.org/class/yago/Property113244109']
# ['http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 'http://dbpedia.org/class/yago/RealProperty113246475']
# ['http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 'http://dbpedia.org/class/yago/Relation100031921']
# ['http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 'http://dbpedia.org/class/yago/Representative110522035']
# ['http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 'http://dbpedia.org/class/yago/Scholar110557854']
# ['http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 'http://dbpedia.org/class/yago/Scientist110560637']
# ['http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 'http://dbpedia.org/class/yago/Serviceman110582746']
# ['http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 'http://dbpedia.org/class/yago/SkilledWorker110605985']
# ['http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 'http://dbpedia.org/class/yago/SocialScientist110619642']
# ['http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 'http://dbpedia.org/class/yago/StockTrader110657835']
# ['http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 'http://dbpedia.org/class/yago/Trader110720453']
# ['http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 'http://dbpedia.org/class/yago/Whole100003553']
# ['http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 'http://dbpedia.org/class/yago/Wikicat20th-centuryBritishWriters']
# ['http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 'http://dbpedia.org/class/yago/Wikicat20th-centuryEconomists']
# ['http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 'http://dbpedia.org/class/yago/Wikicat20th-centuryMathematicians']
# ['http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 'http://dbpedia.org/class/yago/WikicatBibliophiles']
# ['http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 'http://dbpedia.org/class/yago/WikicatBisexualMen']
# ['http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 'http://dbpedia.org/class/yago/WikicatBisexualWriters']
# ['http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 'http://dbpedia.org/class/yago/WikicatBrettonWoodsConferenceDelegates']
# ['http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 'http://dbpedia.org/class/yago/WikicatBritishArtCollectors']
# ['http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 'http://dbpedia.org/class/yago/WikicatBritishCivilServants']
# ['http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 'http://dbpedia.org/class/yago/WikicatBritishEconomists']
# ['http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 'http://dbpedia.org/class/yago/WikicatBritishMathematicians']
# ['http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 'http://dbpedia.org/class/yago/WikicatBritishPeople']
# ['http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 'http://dbpedia.org/class/yago/WikicatBritishPeopleOfWorldWarI']
# ['http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 'http://dbpedia.org/class/yago/WikicatPeopleInFinance']
# ['http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 'http://dbpedia.org/class/yago/WikicatPoliticalScientists']
# ['http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 'http://dbpedia.org/class/yago/WikicatPresidentsOfTheCambridgeUnionSociety']
# ['http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 'http://dbpedia.org/class/yago/WikicatProbabilityTheorists']
# ['http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 'http://dbpedia.org/class/yago/Worker109632518']
# ['http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 'http://dbpedia.org/class/yago/Writer110794014']
# ['http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 'http://dbpedia.org/class/yago/YagoGeoEntity']
# ['http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 'http://dbpedia.org/class/yago/YagoLegalActor']
# ['http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 'http://dbpedia.org/class/yago/YagoLegalActorGeo']
# ['http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 'http://dbpedia.org/class/yago/YagoPermanentlyLocatedEntity']
# ['http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 'http://dbpedia.org/class/yago/WikicatLGBTPeopleFromEngland']
# ['http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 'http://dbpedia.org/class/yago/WikicatLGBTPeopleInAndAroundTheBloomsburyGroup']
# ['http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 'http://dbpedia.org/class/yago/WikicatLGBTPoliticiansFromEngland']
# ['http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 'http://dbpedia.org/class/yago/WikicatLGBTScientistsFromTheUnitedKingdom']
# ['http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 'http://dbpedia.org/class/yago/WikicatLGBTWriters']
# ['http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 'http://dbpedia.org/class/yago/WikicatLGBTWritersFromEngland']
# ['http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 'http://dbpedia.org/class/yago/WikicatLiberalParty(UK)Politicians']
# ['http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 'http://dbpedia.org/class/yago/WikicatMonetaryEconomists']
# ['http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 'http://dbpedia.org/class/yago/WikicatAcademicsOfTheUniversityOfCambridge']
# ['http://www.w3.org/1999/02/22-rdf-syntax-ns#type', "http://dbpedia.org/class/yago/WikicatAlumniOfKing'sCollege,Cambridge"]
# ['http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 'http://dbpedia.org/class/yago/WikicatAnalyticPhilosophers']
# ['http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 'http://dbpedia.org/class/yago/WikicatArtCollectors']
# ['http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 'http://dbpedia.org/class/yago/WikicatBaroniesInThePeerageOfTheUnitedKingdom']
# ['http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 'http://dbpedia.org/class/yago/WikicatBaronsInThePeerageOfTheUnitedKingdom']
# ['http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 'http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#Agent']
# ['http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 'http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#NaturalPerson']
# ['http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 'http://dbpedia.org/ontology/Agent']
# ['http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 'http://www.wikidata.org/entity/Q215627']
# ['http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 'http://www.wikidata.org/entity/Q24229398']
# ['http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 'http://www.wikidata.org/entity/Q5']
# ['http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 'http://dbpedia.org/class/yago/WikicatCompanionsOfTheOrderOfTheBath']
# ['http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 'http://dbpedia.org/class/yago/WikicatEconomicsWriters']
# ['http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 'http://dbpedia.org/class/yago/WikicatEnglishAgnostics']
# ['http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 'http://dbpedia.org/class/yago/WikicatEnglishArtCollectors']
# ['http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 'http://dbpedia.org/class/yago/WikicatEnglishEconomists']
# ['http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 'http://dbpedia.org/class/yago/WikicatEnglishFarmers']
# ['http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 'http://dbpedia.org/class/yago/WikicatEnglishPeople']
# ['http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 'http://dbpedia.org/class/yago/WikicatEnglishPhilanthropists']
# ['http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 'http://dbpedia.org/class/yago/WikicatEnglishPhilosophers']
# ['http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 'http://dbpedia.org/class/yago/WikicatEnglishStockTraders']
# ['http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 'http://dbpedia.org/class/yago/WikicatExtinctBaroniesInThePeerageOfTheUnitedKingdom']
# ['http://www.w3.org/1999/02/22-rdf-syntax-ns#type', "http://dbpedia.org/class/yago/WikicatFellowsOfKing'sCollege,Cambridge"]
# ['http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 'http://dbpedia.org/class/yago/WikicatFellowsOfTheBritishAcademy']
# ['http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 'http://dbpedia.org/ontology/Writer']
# ['http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 'http://dbpedia.org/class/yago/Abstraction100002137']
# ['http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 'http://dbpedia.org/class/yago/Academician109759069']
# ['http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 'http://dbpedia.org/class/yago/Adult109605289']
# ['http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 'http://dbpedia.org/class/yago/Agnostic109779124']
# ['http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 'http://dbpedia.org/class/yago/Alumnus109786338']
# ['http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 'http://dbpedia.org/class/yago/Aristocrat109807754']
# ['http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 'http://dbpedia.org/class/yago/Associate109816771']
# ['http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 'http://dbpedia.org/class/yago/Baron109840520']
# ['http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 'http://dbpedia.org/class/yago/Barony113251906']
# ['http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 'http://dbpedia.org/class/yago/Benefactor109608709']
# ['http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 'http://dbpedia.org/class/yago/Bibliophile109852679']
# ['http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 'http://dbpedia.org/class/yago/Businessperson109882716']
# ['http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 'http://dbpedia.org/class/yago/Capitalist109609232']
# ['http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 'http://dbpedia.org/class/yago/CausalAgent100007347']
# ['http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 'http://dbpedia.org/class/yago/CivilServant109925459']
# ['http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 'http://dbpedia.org/class/yago/Colleague109935990']
# ['http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 'http://dbpedia.org/class/yago/Collector109936620']
# ['http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 'http://dbpedia.org/class/yago/Communicator109610660']
# ['http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 'http://dbpedia.org/class/yago/Companion109945905']
# ['http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 'http://dbpedia.org/class/yago/Creator109614315']
# ['http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 'http://dbpedia.org/class/yago/Delegate110000787']
# ['http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 'http://dbpedia.org/class/yago/Donor110025730']
# ['http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 'http://dbpedia.org/class/yago/Economist110043643']
# ['http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 'http://dbpedia.org/class/yago/Educator110045713']
# ['http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 'http://dbpedia.org/class/yago/Estate113246662']
# ['http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 'http://dbpedia.org/class/yago/Farmer110078806']
# ['http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 'http://dbpedia.org/class/yago/Friend110112591']
# ['http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 'http://dbpedia.org/class/yago/GoodPerson110138767']
# ['http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 'http://dbpedia.org/class/yago/HeadOfState110164747']
# ['http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 'http://dbpedia.org/class/yago/Intellectual109621545']
# ['http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 'http://dbpedia.org/class/yago/Leader109623038']
# ['http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 'http://dbpedia.org/class/yago/LivingThing100004258']
# ['http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 'http://dbpedia.org/class/yago/Male109624168']
# ['http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 'http://dbpedia.org/class/yago/MaleAristocrat110285135']
# ['http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 'http://dbpedia.org/class/yago/Man110287213']
# ['http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 'http://dbpedia.org/class/yago/Mathematician110301261']
# ['http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 'http://dbpedia.org/class/yago/Merchant110309896']
# ['http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 'http://dbpedia.org/class/yago/MilitaryOfficer110317007']
# ['http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 'http://dbpedia.org/class/yago/Negotiator110351874']
# ['http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 'http://dbpedia.org/class/yago/Noble110271677']
# ['http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 'http://dbpedia.org/class/yago/WikicatOfficersOfTheOrderOfLeopold(Belgium)']
# ['http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 'http://dbpedia.org/class/yago/WikicatPeopleEducatedAtEtonCollege']
# ['http://www.w3.org/1999/02/22-rdf-syntax-ns#type', "http://dbpedia.org/class/yago/WikicatPeopleEducatedAtStFaith'sSchool"]
# ['http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 'http://dbpedia.org/class/yago/WikicatPeopleFromCambridge']
# ['http://www.w3.org/2000/01/rdf-schema#label', 'John Maynard Keynes']
# ['http://www.w3.org/2000/01/rdf-schema#label', 'جون مينارد كينز']
# ['http://www.w3.org/2000/01/rdf-schema#label', 'John Maynard Keynes']
# ['http://www.w3.org/2000/01/rdf-schema#label', 'John Maynard Keynes']
# ['http://www.w3.org/2000/01/rdf-schema#label', 'John Maynard Keynes']
# ['http://www.w3.org/2000/01/rdf-schema#label', 'Τζων Μέυναρντ Κέυνς']
# ['http://www.w3.org/2000/01/rdf-schema#label', 'John Maynard Keynes']
# ['http://www.w3.org/2000/01/rdf-schema#label', 'John Maynard Keynes']
# ['http://www.w3.org/2000/01/rdf-schema#label', 'John Maynard Keynes']
# ['http://www.w3.org/2000/01/rdf-schema#label', 'John Maynard Keynes']
# ['http://www.w3.org/2000/01/rdf-schema#label', 'John Maynard Keynes']
# ['http://www.w3.org/2000/01/rdf-schema#label', 'ジョン・メイナード・ケインズ']
# ['http://www.w3.org/2000/01/rdf-schema#label', 'John Maynard Keynes']
# ['http://www.w3.org/2000/01/rdf-schema#label', '존 메이너드 케인스']
# ['http://www.w3.org/2000/01/rdf-schema#label', 'John Maynard Keynes']
# ['http://www.w3.org/2000/01/rdf-schema#label', 'John Maynard Keynes']
# ['http://www.w3.org/2000/01/rdf-schema#label', 'John Maynard Keynes']
# ['http://www.w3.org/2000/01/rdf-schema#label', 'Кейнс, Джон Мейнард']
# ['http://www.w3.org/2000/01/rdf-schema#label', 'Джон Мейнард Кейнс']
# ['http://www.w3.org/2000/01/rdf-schema#label', 'John Maynard Keynes']
# ['http://www.w3.org/2000/01/rdf-schema#label', '约翰·梅纳德·凯恩斯']
# ['http://www.w3.org/2000/01/rdf-schema#comment', 'Ο Τζων Μέυναρντ Κέυνς, πρώτος βαρώνος Κέυνς του Τίλτον (John Maynard Keynes, 5 Ιουνίου 1883 – 21 Απριλίου 1946) ήταν Άγγλος οικονομολόγος, μαθηματικός, καθηγητής πανεπιστημίου, συγγραφέας και ανώτατος κρατικός υπάλληλος. Δημιούργησε, με τα έργα του και τους οπαδούς του, τη λεγόμενη κεϋνσιανή σχολή στην οικονομική επιστήμη. Ο Κέυνς και ο Μίλτον Φρίντμαν ήταν δύο από τους πιο σημαντικούς οικονομολόγους του 20ού αιώνα.']
# ['http://www.w3.org/2000/01/rdf-schema#comment', 'John Maynard Keynes, 1. Baron Keynes [keɪnz] (* 5. Juni 1883 in Cambridge; † 21. April 1946 in Tilton bei Firle, East Sussex) war ein britischer Ökonom, Politiker und Mathematiker. Er zählt zu den bedeutendsten Ökonomen des 20. Jahrhunderts und ist Namensgeber des Keynesianismus. Seine Ideen haben bis heute Einfluss auf ökonomische und politische Theorien.']
# ['http://www.w3.org/2000/01/rdf-schema#comment', 'John Maynard Keynes (Cambridge, Cambridgeshire, Ingalaterra, 1883ko ekainaren 5a - Firle, Ekialdeko Sussex, Ingalaterra, 1946ko apirilaren 21a) ekonomialaria izan zen. Keynesen ekonomia teoria, keynesianismo izenaz, XX. mendeko garrantzitsuenetakoa izan zen.']
# ['http://www.w3.org/2000/01/rdf-schema#comment
# ['http://www.w3.org/2000/01/rdf-schema#comment', 'John Maynard Keynes, Baron Keynes ke-1, CB, FBA ( KEYNZ; 5 Juni 1883 – 21 April 1946), adalah ekonom Inggris yang gagasannya mengubah teori dan praktik ekonomi makro serta kebijakan ekonomi dunia. Ia melanjutkan dan memperbaiki teori sebelumnya yang menjelaskan penyebab terjadinya siklus bisnis. Ia diakui sebagai salah satu ekonom paling berpengaruh abad ke-20 dan pendiri ekonomi makro modern. Pemikiran-pemikirannya menjadi dasar  Keynesian dan semua turunannya.']
# ['http://www.w3.org/2000/01/rdf-schema#comment', 'John Maynard Keynes, 1º barone Keynes di Tilton (/ˈkeɪ̯nz/; Cambridge, 5 giugno 1883 – Tilton, 21 aprile 1946), è stato un economista britannico, padre della macroeconomia e considerato il più influente tra gli economisti del XX secolo.']
# ['http://www.w3.org/2000/01/rdf-schema#comment', "존 메이너드 케인스 남작(영어: John Maynard Keynes, 1st Baron Keynesof Tilton in the Country of Sussex, CB, 1883년 6월 5일 ~ 1946년 4월 21일)은 영국경제학의 대표자이다. 1883년 6월 5일 영국 케임브리지에서 태어났으며, 이튼을 거쳐 케임브리지의 킹스칼리지에서 수학하고, 수학과 우등시험에서 12위로 합격했다. 졸업 후 한 때 인도성에 근무하다가 대학에 돌아와 금융론을 강의했고, 그 후 약 20년간 마샬(Marshall, A.)의 충실한 후계자로서 피구(Pigou, A.C.)와 더불어 케임브리지학파의 쌍벽을 이루었다. 또 Royal Economic Society의 서기로 있었고 Economic Journal의 명편집자로서 잡지를 세계적으로 권위 있는 경제학잡지로 육성했다. 이전의 학설들을 토대로 하여 '케인스 경제학'이라는 독창적인 이론을 창시해, 경기후퇴와 불황에 대해서 재정정책을 사용할 것을 강력하게 주장하였다."]
# ['http://www.w3.org/2000/01/rdf-schema#comment', 'John Maynard Keynes, 1. baron Keynes (ur. 5 czerwca 1883 w Cambridge, zm. 21 kwietnia 1946 w Firle) – angielski ekonomista, twórca teorii interwencjonizmu państwowego w dziedzinie ekonomii i finansów państwowych. Był synem logika i ekonomisty Johna Neville’a Keynesa (1852–1949) i  (1861–1958), brytyjskiej pisarki.']
# ['http://www.w3.org/2000/01/rdf-schema#comment', 'Джон Ме́йнард Кейнс, 1-й барон Кейнс CB (англ. John Maynard Keynes, 1st Baron Keynes; 5 июня 1883 года, Кембридж — 21 апреля 1946 года, поместье Тилтон, графство Сассекс) — английский экономист, основатель кейнсианского направления в экономической науке. Кроме того, Кейнс создал оригинальную теорию вероятностей, основанную на предположении, что вероятность является логическим, а не числовым отношением.']
# ['http://www.w3.org/2000/01/rdf-schema#comment', 'John Maynard Keynes (Cambridge, 5 de junho de 1883 — Tilton, East Sussex, 21 de abril de 1946), foi um economista britânico cujas ideias mudaram fundamentalmente a teoria e prática da macroeconomia, bem como as políticas económicas instituídas pelos governos. Ele fundamentou as suas teorias noutros trabalhos anteriores que analisavam as causas dos ciclos econômicos, refinando-as enormemente e tornando-se amplamente reconhecido como um dos economistas mais influentes do século XX e o fundador da macroeconomia moderna. O trabalho de Keynes é a base para a escola de pensamento conhecida como keynesianismo, bem como suas diversas ramificações.']
# ['http://www.w3.org/2000/01/rdf-schema#comment', 'John Maynard Keynes, efter 1942 Baron Keynes of Tilton (Lord Keynes), född 5 juni 1883 i Cambridge i Cambridgeshire, död 21 april 1946 i  i East Sussex, var en brittisk nationalekonom och filosof. Han var son till John Neville Keynes.']
# ['http://xmlns.com/foaf/0.1/name', 'The Lord Keynes']
# ['http://www.w3.org/2004/02/skos/core#exactMatch', 'http://globalwordnet.org/ili/i95815']
# ['http://dbpedia.org/property/name', 'John Maynard Keynes']
# ['http://dbpedia.org/property/name', 'The Lord Keynes']
# ['http://xmlns.com/foaf/0.1/depiction', 'http://commons.wikimedia.org/wiki/Special:FilePath/Keynes_1933.jpg']
# ['http://xmlns.com/foaf/0.1/isPrimaryTopicOf', 'http://en.wikipedia.org/wiki/John_Maynard_Keynes']
# ['http://dbpedia.org/ontology/thumbnail', 'http://commons.wikimedia.org/wiki/Special:FilePath/Keynes_1933.jpg?width=300']
# ['http://dbpedia.org/ontology/deathPlace', 'http://dbpedia.org/resource/Firle']
# ['http://dbpedia.org/ontology/deathPlace', 'http://dbpedia.org/resource/Sussex']
# ['http://dbpedia.org/ontology/deathPlace', 'http://dbpedia.org/resource/England']
# ['http://dbpedia.org/property/deathPlace', 'Tilton, near Firle, Sussex, England']
# ['http://dbpedia.org/ontology/deathDate', '1946-04-21']
# ['http://dbpedia.org/ontology/birthPlace', 'http://dbpedia.org/resource/Cambridge']
# ['http://dbpedia.org/ontology/birthPlace', 'http://dbpedia.org/resource/Cambridgeshire']
# ['http://dbpedia.org/ontology/birthPlace', 'http://dbpedia.org/resource/England']
# ['http://dbpedia.org/property/birthPlace', 'Cambridge, Cambridgeshire, England']
# ['http://dbpedia.org/ontology/birthDate', '1883-06-05']
# ['http://purl.org/dc/terms/subject', 'http://dbpedia.org/resource/Category:British_Empire_in_World_War_II']
# ['http://purl.org/dc/terms/subject', 'http://dbpedia.org/resource/Category:20th-century_British_writers']
# ['http://purl.org/dc/terms/subject', 'http://dbpedia.org/resource/Category:20th-century_economists']
# ['http://purl.org/dc/terms/subject', 'http://dbpedia.org/resource/Category:LGBT_politicians_from_England']
# ['http://purl.org/dc/terms/subject', 'http://dbpedia.org/resource/Category:LGBT_writers_from_England']
# ['http://purl.org/dc/terms/subject', 'http://dbpedia.org/resource/Category:People_educated_at_Eton_College']
# ['http://purl.org/dc/terms/subject', 'http://dbpedia.org/resource/Category:Academics_of_the_University_of_Cambridge']
# ['http://purl.org/dc/terms/subject', 'http://dbpedia.org/resource/Category:Historians_of_economic_thought']
# ['http://purl.org/dc/terms/subject', 'http://dbpedia.org/resource/Category:20th-century_philosophers']
# ['http://purl.org/dc/terms/subject', 'http://dbpedia.org/resource/Category:1883_births']
# ['http://purl.org/dc/terms/subject', 'http://dbpedia.org/resource/Category:1946_deaths']
# ['http://purl.org/dc/terms/subject', 'http://dbpedia.org/resource/Category:Companions_of_the_Order_of_the_Bath']
# ['http://purl.org/dc/terms/subject', "http://dbpedia.org/resource/Category:Alumni_of_King's_College,_Cambridge"]
# ['http://purl.org/dc/terms/subject', 'http://dbpedia.org/resource/Category:Cambridge_University_Moral_Sciences_Club']
# ['http://purl.org/dc/terms/subject', 'http://dbpedia.org/resource/Category:Chatham_House_people']
# ['http://purl.org/dc/terms/subject', 'http://dbpedia.org/resource/Category:Keynes_family']
# ['http://purl.org/dc/terms/subject', 'http://dbpedia.org/resource/Category:Keynesians']
# ['http://purl.org/dc/terms/subject', 'http://dbpedia.org/resource/Category:LGBT_peers']
# ['http://purl.org/dc/terms/subject', 'http://dbpedia.org/resource/Category:LGBT_scientists_from_the_United_Kingdom']
# ['http://purl.org/dc/terms/subject', 'http://dbpedia.org/resource/Category:Liberal_Party_(UK)_hereditary_peers']
# ['http://purl.org/dc/terms/subject', 'http://dbpedia.org/resource/Category:People_from_Cambridge']
# ['http://purl.org/dc/terms/subject', 'http://dbpedia.org/resource/Category:Presidents_of_the_Cambridge_Union']
# ['http://purl.org/dc/terms/subject', 'http://dbpedia.org/resource/Category:Presidents_of_the_Econometric_Society']
# ['http://purl.org/dc/terms/subject', 'http://dbpedia.org/resource/Category:Barons_in_the_Peerage_of_the_United_Kingdom']
# ['http://purl.org/dc/terms/subject', 'http://dbpedia.org/resource/Category:Bisexual_academics']
# ['http://purl.org/dc/terms/subject', 'http://dbpedia.org/resource/Category:Bisexual_men']
# ['http://purl.org/dc/terms/subject', 'http://dbpedia.org/resource/Category:Bisexual_writers']
# ['http://purl.org/dc/terms/subject', 'http://dbpedia.org/resource/Category:Bloomsbury_Group']
# ['http://purl.org/dc/terms/subject', "http://dbpedia.org/resource/Category:Fellows_of_King's_College,_Cambridge"]
# ['http://purl.org/dc/terms/subject', 'http://dbpedia.org/resource/Category:Fellows_of_the_British_Academy']
# ['http://purl.org/dc/terms/subject', 'http://dbpedia.org/resource/Category:Fellows_of_the_Econometric_Society']
# ['http://purl.org/dc/terms/subject', 'http://dbpedia.org/resource/Category:Economics_journal_editors']
# ['http://purl.org/dc/terms/subject', 'http://dbpedia.org/resource/Category:Bretton_Woods_Conference_delegates']
# ['http://purl.org/dc/terms/subject', 'http://dbpedia.org/resource/Category:British_Zionists']
# ['http://purl.org/dc/terms/subject', 'http://dbpedia.org/resource/Category:British_bibliophiles']
# ['http://purl.org/dc/terms/subject', 'http://dbpedia.org/resource/Category:British_conscientious_objectors']
# ['http://purl.org/dc/terms/subject', 'http://dbpedia.org/resource/Category:British_social_liberals']
# ['http://purl.org/dc/terms/subject', "http://dbpedia.org/resource/Category:People_educated_at_St_Faith's_School"]
# ['http://purl.org/dc/terms/subject', 'http://dbpedia.org/resource/Category:Keynesian_economics']
# ['http://purl.org/dc/terms/subject', 'http://dbpedia.org/resource/Category:John_Maynard_Keynes']
# ['http://purl.org/dc/terms/subject', 'http://dbpedia.org/resource/Category:English_art_collectors']
# ['http://purl.org/dc/terms/subject', 'http://dbpedia.org/resource/Category:English_atheists']
# ['http://purl.org/dc/terms/subject', 'http://dbpedia.org/resource/Category:English_economists']
# ['http://purl.org/dc/terms/subject', 'http://dbpedia.org/resource/Category:English_eugenicists']
# ['http://purl.org/dc/terms/subject', 'http://dbpedia.org/resource/Category:English_farmers']
# ['http://purl.org/dc/terms/subject', 'http://dbpedia.org/resource/Category:English_investors']
# ['http://purl.org/dc/terms/subject', 'http://dbpedia.org/resource/Category:English_philanthropists']
# ['http://purl.org/dc/terms/subject', 'http://dbpedia.org/resource/Category:English_philosophers']
# ['http://purl.org/dc/terms/subject', 'http://dbpedia.org/resource/Category:English_stock_traders']
# ['http://purl.org/dc/terms/subject', 'http://dbpedia.org/resource/Category:Probability_theorists']
# ['http://dbpedia.org/ontology/wikiPageID', '37973']
# ['http://dbpedia.org/ontology/wikiPageRevisionID', '985840536']
# ['http://dbpedia.org/ontology/wikiPageWikiLink', 'http://dbpedia.org/resource/Category:British_Empire_in_World_War_II']
# ['http://dbpedia.org/ontology/wikiPageWikiLink', 'http://dbpedia.org/resource/Category:20th-century_British_writers']
# ['http://dbpedia.org/ontology/wikiPageWikiLink', 'http://dbpedia.org/resource/Category:20th-century_economists']
# ['http://dbpedia.org/ontology/wikiPageWikiLink', 'http://dbpedia.org/resource/AD–AS_model']
# ['http://dbpedia.org/ontology/wikiPageWikiLink', 'http://dbpedia.org/resource/Category:LGBT_politicians_from_England']
# ['http://dbpedia.org/ontology/wikiPageWikiLink', 'http://dbpedia.org/resource/Category:LGBT_writers_from_England']
# ['http://dbpedia.org/ontology/wikiPageWikiLink', 'http://dbpedia.org/resource/Category:People_educated_at_Eton_College']
# ['http://dbpedia.org/ontology/wikiPageWikiLink', 'http://dbpedia.org/resource/Ludwig_Wittgenstein']
# ['http://dbpedia.org/ontology/wikiPageWikiLink', 'http://dbpedia.org/resource/Ludwig_von_Mises']
# ['http://dbpedia.org/ontology/wikiPageWikiLink', 'http://dbpedia.org/resource/Lydia_Lopokova']
# ['http://dbpedia.org/ontology/wikiPageWikiLink', 'http://dbpedia.org/resource/Lytton_Strachey']
# ['http://dbpedia.org/ontology/wikiPageWikiLink', 'http://dbpedia.org/resource/MIT_Press']
# ['http://dbpedia.org/ontology/wikiPageWikiLink', 'http://dbpedia.org/resource/MSI_Reproductive_Choices']
# ['http://dbpedia.org/ontology/wikiPageWikiLink', 'http://dbpedia.org/resource/Macmillan_Publishers']
# ['http://dbpedia.org/ontology/wikiPageWikiLink', 'http://dbpedia.org/resource/Magdalene_College,_Cambridge']
# ['http://dbpedia.org/ontology/wikiPageWikiLink', 'http://dbpedia.org/resource/Convertibility']
# ['http://dbpedia.org/ontology/wikiPageWikiLink', 'http://dbpedia.org/resource/Unemployment']
# ['http://dbpedia.org/ontology/wikiPageWikiLink', 'http://dbpedia.org/resource/United_States_Department_of_the_Treasury']
# ['http://dbpedia.org/ontology/wikiPageWikiLink', 'http://dbpedia.org/resource/University_Pitt_Club']
# ['http://dbpedia.org/ontology/wikiPageWikiLink', 'http://dbpedia.org/resource/Vanessa_Bell']
# ['http://dbpedia.org/ontology/wikiPageWikiLink', 'http://dbpedia.org/resource/Wall_Street_Crash_of_1929']
# ['http://dbpedia.org/ontology/wikiPageWikiLink', 'http://dbpedia.org/resource/Effective_demand']
# ['http://dbpedia.org/ontology/wikiPageWikiLink', 'http://dbpedia.org/resource/Monetarism']
# ['http://dbpedia.org/ontology/wikiPageWikiLink', 'http://dbpedia.org/resource/Political_Economy_Club_(1909)']
# ['http://dbpedia.org/ontology/wikiPageWikiLink', 'http://dbpedia.org/resource/Category:Academics_of_the_University_of_Cambridge']
# ['http://dbpedia.org/ontology/wikiPageWikiLink', 'http://dbpedia.org/resource/Bisexuality']
# ['http://dbpedia.org/ontology/wikiPageWikiLink', 'http://dbpedia.org/resource/Category:Historians_of_economic_thought']
# ['http://dbpedia.org/ontology/wikiPageWikiLink', 'http://dbpedia.org/resource/A_Monetary_History_of_the_United_States']
# ['http://dbpedia.org/ontology/wikiPageWikiLink', 'http://dbpedia.org/resource/A_Treatise_on_Money']
# ['http://dbpedia.org/ontology/wikiPageWikiLink', 'http://dbpedia.org/resource/A_Treatise_on_Probability']
# ['http://dbpedia.org/ontology/wikiPageWikiLink', 'http://dbpedia.org/resource/Dilly_Knox']
# ['http://dbpedia.org/ontology/wikiPageWikiLink', 'http://dbpedia.org/resource/Dividend']
# ['http://dbpedia.org/ontology/wikiPageWikiLink', 'http://dbpedia.org/resource/Don_Patinkin']
# ['http://dbpedia.org/ontology/wikiPageWikiLink', 'http://dbpedia.org/resource/Anglo-American_loan']
# ['http://dbpedia.org/ontology/wikiPageWikiLink', 'http://dbpedia.org/resource/Gold_standard']
# ['http://dbpedia.org/ontology/wikiPageWikiLink', 'http://dbpedia.org/resource/Google_Scholar']
# ['http://dbpedia.org/ontology/wikiPageWikiLink', 'http://dbpedia.org/resource/Gordon_Brown']
# ['http://dbpedia.org/ontology/wikiPageWikiLink', 'http://dbpedia.org/resource/Keynesian_economics']
# ['http://dbpedia.org/ontology/wikiPageWikiLink', "http://dbpedia.org/resource/King's_College,_Cambridge"]
# ['http://dbpedia.org/ontology/wikiPageWikiLink', 'http://dbpedia.org/resource/Knut_Wicksell']
# ['http://dbpedia.org/ontology/wikiPageWikiLink', 'http://dbpedia.org/resource/President_of_the_United_States']
# ['http://dbpedia.org/ontology/wikiPageWikiLink', 'http://dbpedia.org/resource/Empirical_evidence']
# ['http://dbpedia.org/ontology/wikiPageWikiLink', 'http://dbpedia.org/resource/Gnomes_of_Zürich']
# ['http://dbpedia.org/ontology/wikiPageWikiLink', "http://dbpedia.org/resource/Gresham's_law"]
# ['http://dbpedia.org/ontology/wikiPageWikiLink', 'http://dbpedia.org/resource/Hard_money_(policy)']
# ['http://dbpedia.org/ontology/wikiPageWikiLink', 'http://dbpedia.org/resource/Economic_interventionism']
# ['http://dbpedia.org/ontology/wikiPageWikiLink', 'http://dbpedia.org/resource/IS–LM_model']
# ['http://dbpedia.org/ontology/wikiPageWikiLink', 'http://dbpedia.org/resource/Inflation']
# ['http://dbpedia.org/ontology/wikiPageWikiLink', 'http://dbpedia.org/resource/International_Clearing_Union']
# ['http://dbpedia.org/ontology/wikiPageWikiLink', 'http://dbpedia.org/resource/Invisible_hand']
# ['http://dbpedia.org/ontology/wikiPageWikiLink', 'http://dbpedia.org/resource/Mainstream_economics']
# ['http://dbpedia.org/ontology/wikiPageWikiLink', 'http://dbpedia.org/resource/Political_economy']
# ['http://dbpedia.org/ontology/wikiPageWikiLink', 'http://dbpedia.org/resource/Category:20th-century_philosophers']
# ['http://dbpedia.org/ontology/wikiPageWikiLink', 'http://dbpedia.org/resource/Category:1883_births']
# ['http://dbpedia.org/ontology/wikiPageWikiLink', 'http://dbpedia.org/resource/Category:1946_deaths']
# ['http://dbpedia.org/ontology/wikiPageWikiLink', 'http://dbpedia.org/resource/Alan_Blinder']
# ['http://dbpedia.org/ontology/wikiPageWikiLink', 'http://dbpedia.org/resource/Alfred_Marshall']
# ['http://dbpedia.org/ontology/wikiPageWikiLink', 'http://dbpedia.org/resource/Alistair_Darling']
# ['http://dbpedia.org/ontology/wikiPageWikiLink', 'http://dbpedia.org/resource/Allies_of_World_War_II']
# ['http://dbpedia.org/ontology/wikiPageWikiLink', 'http://dbpedia.org/resource/Category:Companions_of_the_Order_of_the_Bath']
# ['http://dbpedia.org/ontology/wikiPageWikiLink', 'http://dbpedia.org/resource/Chancellor_of_the_Exchequer']
# ['http://dbpedia.org/ontology/wikiPageWikiLink', 'http://dbpedia.org/resource/Financial_Times']
# ['http://dbpedia.org/ontology/wikiPageWikiLink', 'http://dbpedia.org/resource/Financial_crisis_of_2007–2008']
# ['http://dbpedia.org/ontology/wikiPageWikiLink', 'http://dbpedia.org/resource/Firle']
# ['http://dbpedia.org/ontology/wikiPageWikiLink', 'http://dbpedia.org/resource/Fitzwilliam_Museum']
# ['http://dbpedia.org/ontology/wikiPageWikiLink', 'http://dbpedia.org/resource/Florence_Ada_Keynes']
# ['http://dbpedia.org/ontology/wikiPageWikiLink', 'http://dbpedia.org/resource/OECD']
# ['http://dbpedia.org/ontology/wikiPageWikiLink', 'http://dbpedia.org/resource/Fiscal_policy']
# ['http://dbpedia.org/ontology/wikiPageWikiLink', 'http://dbpedia.org/resource/Free_market']
# ['http://dbpedia.org/ontology/wikiPageWikiLink', 'http://dbpedia.org/resource/Galton_Institute']
# ['http://dbpedia.org/ontology/wikiPageWikiLink', 'http://dbpedia.org/resource/Government-sponsored_enterprise']
# ['http://dbpedia.org/ontology/wikiPageWikiLink', 'http://dbpedia.org/resource/The_General_Theory_of_Employment,_Interest_and_Money']
# ['http://dbpedia.org/ontology/wikiPageWikiLink', 'http://dbpedia.org/resource/Fiscal_multiplier']
# ['http://dbpedia.org/ontology/wikiPageWikiLink', 'http://dbpedia.org/resource/Multiplier_(economics)']
# ['http://dbpedia.org/ontology/wikiPageWikiLink', 'http://dbpedia.org/resource/Neoclassical_economics']
# ['http://dbpedia.org/ontology/wikiPageWikiLink', 'http://dbpedia.org/resource/Great_Recession']
# ['http://dbpedia.org/ontology/wikiPageWikiLink', 'http://dbpedia.org/resource/Nominal_rigidity']
# ['http://dbpedia.org/ontology/wikiPageWikiLink', 'http://dbpedia.org/resource/The_Right_Honourable']
# ['http://dbpedia.org/ontology/wikiPageWikiLink', 'http://dbpedia.org/resource/Value_investing']
# ['http://dbpedia.org/ontology/wikiPageWikiLink', 'http://dbpedia.org/resource/Victorian_era']
# ['http://dbpedia.org/ontology/wikiPageWikiLink', 'http://dbpedia.org/resource/Victorian_morality']
# ['http://dbpedia.org/ontology/wikiPageWikiLink', 'http://dbpedia.org/resource/Eugenics']
# ['http://dbpedia.org/ontology/wikiPageWikiLink', 'http://dbpedia.org/resource/Full_employment']
# ['http://dbpedia.org/ontology/wikiPageWikiLink', 'http://dbpedia.org/resource/Heavenly_Twins_(Sumner_and_Cunliffe)']
# ['http://dbpedia.org/ontology/wikiPageWikiLink', "http://dbpedia.org/resource/Category:Alumni_of_King's_College,_Cambridge"]
# ['http://dbpedia.org/ontology/wikiPageWikiLink', 'http://dbpedia.org/resource/Category:Cambridge_University_Moral_Sciences_Club']
# ['http://dbpedia.org/ontology/wikiPageWikiLink', 'http://dbpedia.org/resource/Category:Chatham_House_people']
# ['http://dbpedia.org/ontology/wikiPageWikiLink', 'http://dbpedia.org/resource/Bailout']
# ['http://dbpedia.org/ontology/wikiPageWikiLink', 'http://dbpedia.org/resource/Bank_of_England']
# ['http://dbpedia.org/ontology/wikiPageWikiLink', 'http://dbpedia.org/resource/Banknote']
# ['http://dbpedia.org/ontology/wikiPageWikiLink', 'http://dbpedia.org/resource/Barack_Obama']
# ['http://dbpedia.org/ontology/wikiPageWikiLink', 'http://dbpedia.org/resource/London_School_of_Economics']
# ['http://dbpedia.org/ontology/wikiPageWikiLink', 'http://dbpedia.org/resource/Deficit_spending']
# ['http://dbpedia.org/ontology/wikiPageWikiLink', 'http://dbpedia.org/resource/Deflation']
# ['http://dbpedia.org/ontology/wikiPageWikiLink', 'http://dbpedia.org/resource/Demand-side_economics']
# ['http://dbpedia.org/ontology/wikiPageWikiLink', 'http://dbpedia.org/resource/Economic_history']
# ['http://dbpedia.org/ontology/wikiPageWikiLink', 'http://dbpedia.org/resource/Economic_policy']
# ['http://dbpedia.org/ontology/wikiPageWikiLink', 'http://dbpedia.org/resource/Post-war_consensus']
# ['http://dbpedia.org/ontology/wikiPageWikiLink', 'http://dbpedia.org/resource/Neo-Keynesian_economics']
# ['http://dbpedia.org/ontology/wikiPageWikiLink', "http://dbpedia.org/resource/Women's_rights"]
# ['http://dbpedia.org/ontology/wikiPageWikiLink', 'http://dbpedia.org/resource/Stephen_A._Schuker']
# ['http://dbpedia.org/ontology/wikiPageWikiLink', 'http://dbpedia.org/resource/1945_United_Kingdom_general_election']
# ['http://dbpedia.org/ontology/wikiPageWikiLink', 'http://dbpedia.org/resource/1918_United_Kingdom_general_election']
# ['http://dbpedia.org/ontology/wikiPageWikiLink', 'http://dbpedia.org/resource/Cambridge']
# ['http://dbpedia.org/ontology/wikiPageWikiLink', 'http://dbpedia.org/resource/Cambridge_Arts_Theatre']
# ['http://dbpedia.org/ontology/wikiPageWikiLink', 'http://dbpedia.org/resource/Cambridge_University_Press']
# ['http://dbpedia.org/ontology/wikiPageWikiLink', 'http://dbpedia.org/resource/Cambridgeshire']
# ['http://dbpedia.org/ontology/wikiPageWikiLink', 'http://dbpedia.org/resource/Capitalism']
# ['http://dbpedia.org/ontology/wikiPageWikiLink', 'http://dbpedia.org/resource/Category:Keynes_family']
# ['http://dbpedia.org/ontology/wikiPageWikiLink', 'http://dbpedia.org/resource/Category:Keynesians']
# ['http://dbpedia.org/ontology/wikiPageWikiLink', 'http://dbpedia.org/resource/Category:LGBT_peers']
# ['http://dbpedia.org/ontology/wikiPageWikiLink', 'http://dbpedia.org/resource/Category:LGBT_scientists_from_the_United_Kingdom']
# ['http://dbpedia.org/ontology/wikiPageWikiLink', 'http://dbpedia.org/resource/Category:Liberal_Party_(UK)_hereditary_peers']
# ['http://dbpedia.org/ontology/wikiPageWikiLink', 'http://dbpedia.org/resource/Category:People_from_Cambridge']
# ['http://dbpedia.org/ontology/wikiPageWikiLink', 'http://dbpedia.org/resource/Category:Presidents_of_the_Cambridge_Union']
# ['http://dbpedia.org/ontology/wikiPageWikiLink', 'http://dbpedia.org/resource/Clement_Attlee']
# ['http://dbpedia.org/ontology/wikiPageWikiLink', 'http://dbpedia.org/resource/Gary_Becker']
# ['http://dbpedia.org/ontology/wikiPageWikiLink', 'http://dbpedia.org/resource/General_Agreement_on_Tariffs_and_Trade']
# ['http://dbpedia.org/ontology/wikiPageWikiLink', 'http://dbpedia.org/resource/
# ['http://dbpedia.org/ontology/abstract', 'John Maynard Keynes, 1º barone Keynes di Tilton (/ˈkeɪ̯nz/; Cambridge, 5 giugno 1883 – Tilton, 21 aprile 1946), è stato un economista britannico, padre della macroeconomia e considerato il più influente tra gli economisti del XX secolo. Considerato da alcuni come l\'Einstein dell\'economia per le sue intuizioni geniali e rivoluzionarie, le sue idee sono state sviluppate e formalizzate nel dopoguerra dagli economisti della scuola keynesiana; a quest\'ultima viene spesso contrapposta la scuola monetarista (o scuola di Chicago), che si originò nel secondo dopoguerra dalle teorie liberiste di Milton Friedman, e la scuola austriaca (von Mises e von Hayek). I suoi contributi alla teoria economica, espressi nel saggio Teoria generale dell\'occupazione, dell\'interesse e della moneta, hanno dato origine infatti alla cosiddetta "rivoluzione keynesiana" che, in contrasto con la teoria economica neoclassica, ha sostenuto la necessità dell\'intervento pubblico statale nell\'economia con misure di politica di bilancio e monetaria, qualora un\'insufficiente domanda aggregata non riesca a garantire la piena occupazione nel sistema capitalista, in particolare nella fase di crisi del ciclo economico, promuovendo dunque una forma di economia mista.']
# ['http://dbpedia.org/ontology/abstract', '初代ケインズ男爵、ジョン・メイナード・ケインズ（John Maynard Keynes、1st Baron Keynes、1883年6月5日 - 1946年4月21日）は、イギリスの経済学者、官僚、貴族。イングランド、ケンブリッジ出身。20世紀における最重要人物の一人であり、経済学者の代表的存在である。有効需要に基いてケインズサーカスを率いてマクロ経済学を確立させた。また、戦後の外為体制（ブレトン・ウッズ体制）をめぐりハリー・ホワイトと案を出し合った。 経済学の大家アルフレッド・マーシャルの弟子であり、論敵アーサー・セシル・ピグーとは兄弟弟子であった。また、ルートヴィヒ・ウィトゲンシュタインやブルームズベリー・グループとの交流が有名である。']
# ['http://dbpedia.org/ontology/abstract', "존 메이너드 케인스 남작(영어: John Maynard Keynes, 1st Baron Keynesof Tilton in the Country of Sussex, CB, 1883년 6월 5일 ~ 1946년 4월 21일)은 영국경제학의 대표자이다. 1883년 6월 5일 영국 케임브리지에서 태어났으며, 이튼을 거쳐 케임브리지의 킹스칼리지에서 수학하고, 수학과 우등시험에서 12위로 합격했다. 졸업 후 한 때 인도성에 근무하다가 대학에 돌아와 금융론을 강의했고, 그 후 약 20년간 마샬(Marshall, A.)의 충실한 후계자로서 피구(Pigou, A.C.)와 더불어 케임브리지학파의 쌍벽을 이루었다. 또 Royal Economic Society의 서기로 있었고 Economic Journal의 명편집자로서 잡지를 세계적으로 권위 있는 경제학잡지로 육성했다. 이전의 학설들을 토대로 하여 '케인스 경제학'이라는 독창적인 이론을 창시해, 경기후퇴와 불황에 대해서 재정정책을 사용할 것을 강력하게 주장하였다. 케인스의 이론들은 케인스 경제학의 뿌리가 되었을 뿐만 아니라 다른 거시경제학파들에도 큰 영향을 미쳐서, 케인스는 현대 거시경제학의 창시자들 중 한명으로 널리 알려져 있다. 20세기에서 가장 큰 영향을 미친 경제학자로 인정받고 있기도 하다. 케인스는 1930년대에 《고용·이자 및 화폐의 일반 이론》, 흔히 일반이론이라고 불리는 책을 발표하였다. 이 책은 기존의 신고전파 경제학자들의 시장주의를 비판함과 동시에 유효수요이론을 제시하였다. 제2차 세계 대전의 발발 후엔 선진 서양국가들은 케인스의 경제정책을 채택하였다. 후에 1950년대
# ['http://dbpedia.org/ontology/birthYear', '1883']
# ['http://dbpedia.org/ontology/deathYear', '1946']
# ['http://dbpedia.org/ontology/almaMater', 'http://dbpedia.org/resource/King’s_College,_Cambridge']
# ['http://dbpedia.org/ontology/almaMater', 'http://dbpedia.org/resource/Eton_College']
# ['http://dbpedia.org/ontology/party', 'http://dbpedia.org/resource/Liberal_Party_(UK)']
# ['http://dbpedia.org/ontology/spouse', 'http://dbpedia.org/resource/Lydia_Lopokova']
# ['http://schema.org/sameAs', 'http://viaf.org/viaf/29551966']
# ['http://dbpedia.org/property/wordnet_type', 'http://www.w3.org/2006/03/wn/wn20/instances/synset-philosopher-noun-1']
# ['http://www.w3.org/ns/prov#wasDerivedFrom', 'http://en.wikipedia.org/wiki/John_Maynard_Keynes?oldid=985840536&ns=0']
# ['http://dbpedia.org/ontology/wikiPageLength', '146297']

# %% [markdown]
# ## Effectifs et propriétés de 'economist' et 'economics'

# %%
sparql = SPARQLWrapper("https://dbpedia.org/sparql") ##, returnFormat=RDFXML)

# %%
q_economist_1 = """
PREFIX  dbo:  <http://dbpedia.org/ontology/>
PREFIX  dbr:  <http://dbpedia.org/resource/>

SELECT DISTINCT ?p ?direction (count(*) AS ?freq)
WHERE
  {   { SELECT  ?p ("out" AS ?direction)
        WHERE
          { dbo:Economist
                      # ?p  ?o
          }
      }
    UNION
      { SELECT  ?p ?direction
        WHERE
          { ?s  ?p  dbo:Economist
            BIND("in" AS ?direction)
          }
      }
  }
GROUP BY ?p ?direction
ORDER BY DESC(?freq)
"""

# %%
q_economist_2 = """
PREFIX  dbo:  <http://dbpedia.org/ontology/>
PREFIX  dbr:  <http://dbpedia.org/resource/>

SELECT  ?p ?direction (count(*) AS ?freq)
WHERE
  {   { SELECT  ?p ("out" AS ?direction)
        WHERE
          { dbr:Economist
                      # ?p  ?o
          }
      }
    UNION
      { SELECT  ?p ?direction
        WHERE
          { ?s  ?p  dbr:Economist
            BIND("in" AS ?direction)
          }
      }
  }
GROUP BY ?p ?direction
ORDER BY DESC(?freq)

"""

# %%
q_economist_3 = """
PREFIX dbo: <http://dbpedia.org/ontology/>
PREFIX dbr: <http://dbpedia.org/resource/>
PREFIX foaf: <http://xmlns.com/foaf/0.1/>

SELECT ?p ?direction (COUNT(*) AS ?freq)
WHERE {
{
SELECT ?p ('out' as ?direction)
WHERE {
       dbr:Economics ?p ?o .
}
}
UNION
{
SELECT ?p  ?direction
WHERE {
       # ?s ?p dbr:Economics .
BIND ('in' as ?direction)
}

}
}
GROUP BY ?p ?direction
ORDER BY DESC(?freq)
"""

# %%
q_economist_4 = """
PREFIX  dbo:  <http://dbpedia.org/ontology/>
PREFIX  dbr:  <http://dbpedia.org/resource/>
PREFIX  foaf: <http://xmlns.com/foaf/0.1/>

SELECT DISTINCT ?p ?direction (count(*) AS ?freq)
WHERE
  {   { SELECT  ?p ?direction
        WHERE
          { ?person  a                     dbo:Economist ;
                     # ?p                    ?o
            BIND("out" AS ?direction)
          }
      }
    UNION
      { SELECT  ?p ?direction
        WHERE
          { ?person  a                     dbo:Economist .
            # ?s       ?p                    ?person
            BIND("in" AS ?direction)
          }
      }
  }
GROUP BY ?p ?direction
ORDER BY DESC(?freq)
"""

# %%
q_economist_4_1 = """
PREFIX  dbo:  <http://dbpedia.org/ontology/>
PREFIX  dbr:  <http://dbpedia.org/resource/>
PREFIX  foaf: <http://xmlns.com/foaf/0.1/>

SELECT DISTINCT ?p ?direction ?freq
WHERE
  {   { SELECT  ?p ?direction (count(*) AS ?freq)
        WHERE
          { ?person  a                     dbo:Economist ;
                     # ?p                    ?o
            BIND("out" AS ?direction)
          }
         GROUP BY ?p ?direction    
      }
    UNION
      { SELECT  ?p ?direction (count(*) AS ?freq)
        WHERE
          { ?person  a                     dbo:Economist .
            # ?s       ?p                    ?person
            BIND("in" AS ?direction)
          }          
         GROUP BY ?p ?direction
      }
  }
ORDER BY DESC(?freq)       
"""

# %%
query_5 = """
PREFIX  dbo:  <http://dbpedia.org/ontology/>
PREFIX  dbr:  <http://dbpedia.org/resource/>
PREFIX dbp: <http://dbpedia.org/property/>
PREFIX  foaf: <http://xmlns.com/foaf/0.1/>

SELECT  ?person ?birthDate
WHERE
{
{ ?person  a                     dbo:Economist ;
   dbp:birthDate ?birthDate.    
# FILTER regex(?birthDate, '\\d{4}')       
FILTER (?birthDate > 1800)
      }

  }
ORDER BY ?birthDate
LIMIT 100
"""

# %%
sparql.setQuery(q_economist_4_1)
sparql.setReturnFormat(JSON)
rc = sparql.queryAndConvert()
# type(rc)

# %%
# Nombre de lignes du résultat
len(rc['results']['bindings'])
# Out:
# 311

# %%
# Inspecter les trois premières lignes
i = 0
for l in rc['results']['bindings']:
    if i < 3:
        print(l)
        i += 1
# Out:
# {'p': {'type': 'uri', 'value': 'http://dbpedia.org/ontology/wikiPageWikiLink'}, 'direction': {'type': 'literal', 'value': 'out'}, 'freq': {'type': 'typed-literal', 'datatype': 'http://www.w3.org/2001/XMLSchema#integer', 'value': '67345'}}
# {'p': {'type': 'uri', 'value': 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'}, 'direction': {'type': 'literal', 'value': 'out'}, 'freq': {'type': 'typed-literal', 'datatype': 'http://www.w3.org/2001/XMLSchema#integer', 'value': '45350'}}
# {'p': {'type': 'uri', 'value': 'http://dbpedia.org/ontology/wikiPageWikiLink'}, 'direction': {'type': 'literal', 'value': 'in'}, 'freq': {'type': 'typed-literal', 'datatype': 'http://www.w3.org/2001/XMLSchema#integer', 'value': '35420'}}

# %%
variables = ('direction', 'p', 'freq')

# %%
r = [print(l) for l in sparql_result_to_list(rc, 400, variables)]
# Out:
# ['out', 'http://dbpedia.org/ontology/wikiPageWikiLink', '67345']
# ['out', 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type', '45350']
# ['in', 'http://dbpedia.org/ontology/wikiPageWikiLink', '35420']
# ['out', 'http://www.w3.org/2002/07/owl#sameAs', '25691']
# ['out', 'http://purl.org/dc/terms/subject', '16596']
# ['out', 'http://dbpedia.org/property/wikiPageUsesTemplate', '13370']
# ['out', 'http://www.w3.org/2000/01/rdf-schema#label', '7992']
# ['out', 'http://www.w3.org/2000/01/rdf-schema#comment', '7944']
# ['out', 'http://dbpedia.org/ontology/abstract', '7944']
# ['out', 'http://dbpedia.org/ontology/wikiPageExternalLink', '7654']
# ['out', 'http://dbpedia.org/property/almaMater', '2426']
# ['out', 'http://dbpedia.org/ontology/almaMater', '2411']
# ['in', 'http://dbpedia.org/ontology/wikiPageRedirects', '2134']
# ['out', 'http://dbpedia.org/property/field', '1962']
# ['out', 'http://dbpedia.org/ontology/field', '1869']
# ['out', 'http://dbpedia.org/property/institution', '1813']
# ['out', 'http://dbpedia.org/ontology/institution', '1772']
# ['out', 'http://xmlns.com/foaf/0.1/name', '1637']
# ['out', 'http://dbpedia.org/ontology/wikiPageID', '1568']
# ['out', 'http://dbpedia.org/ontology/wikiPageRevisionID', '1568']
# ['out', 'http://xmlns.com/foaf/0.1/isPrimaryTopicOf', '1568']
# ['out', 'http://www.w3.org/ns/prov#wasDerivedFrom', '1568']
# ['out', 'http://dbpedia.org/ontology/wikiPageLength', '1568']
# ['in', 'http://xmlns.com/foaf/0.1/primaryTopic', '1568']
# ['out', 'http://dbpedia.org/property/name', '1531']
# ['out', 'http://dbpedia.org/ontology/birthPlace', '1432']
# ['out', 'http://dbpedia.org/property/birthPlace', '1354']
# ['out', 'http://dbpedia.org/property/influences', '1353']
# ['out', 'http://dbpedia.org/ontology/influencedBy', '1305']
# ['out', 'http://dbpedia.org/property/nationality', '1253']
# ['out', 'http://schema.org/sameAs', '1214']
# ['out', 'http://dbpedia.org/property/birthDate', '1186']
# ['out', 'http://dbpedia.org/ontology/birthDate', '1099']
# ['out', 'http://dbpedia.org/ontology/nationality', '844']
# ['in', 'http://dbpedia.org/property/influences', '737']
# ['out', 'http://dbpedia.org/property/influenced', '712']
# ['out', 'http://dbpedia.org/ontology/influenced', '694']
# ['in', 'http://dbpedia.org/ontology/influencedBy', '691']
# ['out', 'http://dbpedia.org/property/contributions', '645']
# ['in', 'http://dbpedia.org/ontology/wikiPageDisambiguates', '642']
# ['out', 'http://dbpedia.org/property/awards', '604']
# ['out', 'http://dbpedia.org/property/repecPrefix', '603']
# ['out', 'http://dbpedia.org/property/repecId', '601']
# ['out', 'http://dbpedia.org/property/doctoralStudents', '591']
# ['out', 'http://dbpedia.org/property/doctoralAdvisor', '588']
# ['out', 'http://dbpedia.org/property/schoolTradition', '504']
# ['out', 'http://dbpedia.org/ontology/award', '482']
# ['in', 'http://dbpedia.org/property/doctoralAdvisor', '474']
# ['out', 'http://dbpedia.org/ontology/deathPlace', '462']
# ['out', 'http://dbpedia.org/ontology/thumbnail', '459']
# ['out', 'http://xmlns.com/foaf/0.1/depiction', '459']
# ['out', 'http://dbpedia.org/property/deathDate', '448']
# ['in', 'http://dbpedia.org/ontology/influenced', '436']
# ['in', 'http://dbpedia.org/property/doctoralStudents', '430']
# ['in', 'http://dbpedia.org/property/influenced', '430']
# ['out', 'http://dbpedia.org/property/deathPlace', '427']
# ['out', 'http://dbpedia.org/ontology/deathDate', '422']
# ['out', 'http://dbpedia.org/ontology/depictionDescription', '405']
# ['out', 'http://dbpedia.org/property/caption', '379']
# ['out', 'http://dbpedia.org/property/institutions', '266']
# ['out', 'http://dbpedia.org/property/portal', '223']
# ['out', 'http://dbpedia.org/property/spouse', '188']
# ['out', 'http://dbpedia.org/property/imageSize', '162']
# ['out', 'http://xmlns.com/foaf/0.1/homepage', '150']
# ['out', 'http://dbpedia.org/property/birthName', '144']
# ['out', 'http://dbpedia.org/property/title', '143']
# ['in', 'http://dbpedia.org/property/author', '141']
# ['in', 'http://dbpedia.org/ontology/author', '139']
# ['out', 'http://dbpedia.org/property/years', '125']
# ['in', 'http://dbpedia.org/ontology/doctoralAdvisor', '94']
# ['out', 'http://dbpedia.org/property/website', '93']
# ['out', 'http://dbpedia.org/property/wordnet_type', '81']
# ['in', 'http://dbpedia.org/ontology/doctoralStudent', '81']
# ['out', 'http://dbpedia.org/property/after', '77']
# ['out', 'http://dbpedia.org/property/before', '71']
# ['in', 'http://dbpedia.org/property/before', '70']
# ['out', 'http://dbpedia.org/property/citizenship', '68']
# ['in', 'http://dbpedia.org/property/after', '66']
# ['out', 'http://dbpedia.org/property/date', '58']
# ['in', 'http://dbpedia.org/property/candidate', '54']
# ['out', 'http://dbpedia.org/property/nativeName', '49']
# ['in', 'http://dbpedia.org/property/alongside', '49']
# ['in', 'http://dbpedia.org/property/spouse', '46']
# ['out', 'http://dbpedia.org/property/alongside', '45']
# ['out', 'http://dbpedia.org/property/notes', '43']
# ['in', 'http://dbpedia.org/ontology/editor', '40']
# ['out', 'http://dbpedia.org/property/bot', '38']
# ['out', 'http://dbpedia.org/property/fixAttempted', '38']
# ['in', 'http://dbpedia.org/property/editor', '37']
# ['in', 'http://dbpedia.org/ontology/spouse', '32']
# ['in', 'http://dbpedia.org/property/doctoralAdvisors', '31']
# ['in', 'http://dbpedia.org/ontology/keyPerson', '31']
# ['out', 'http://dbpedia.org/property/academicAdvisors', '30']
# ['out', 'http://dbpedia.org/property/id', '29']
# ['out', 'http://dbpedia.org/property/notableStudents', '26']
# ['out', 'http://dbpedia.org/property/url', '26']
# ['in', 'http://dbpedia.org/property/name', '26']
# ['out', 'http://dbpedia.org/property/nativeNameLang', '25']
# ['out', 'http://dbpedia.org/property/doctoralAdvisors', '24']
# ['in', 'http://dbpedia.org/property/founder', '24']
# ['in', 'http://dbpedia.org/property/academicAdvisors', '24']
# ['in', 'http://dbpedia.org/property/leaderName', '23']
# ['in', 'http://dbpedia.org/ontology/person', '23']
# ['in', 'http://dbpedia.org/property/notableStudents', '20']
# ['in', 'http://dbpedia.org/ontology/successor', '20']
# ['in', 'http://dbpedia.org/property/keyPeople', '20']
# ['in', 'http://dbpedia.org/ontology/foundedBy', '20']
# ['in', 'http://www.w3.org/2002/07/owl#differentFrom', '19']
# ['in', 'http://dbpedia.org/property/successor', '18']
# ['out', 'http://dbpedia.org/property/honorificPrefix', '17']
# ['in', 'http://dbpedia.org/property/starring', '17']
# ['out', 'http://www.w3.org/2002/07/owl#differentFrom', '16']
# ['in', 'http://dbpedia.org/ontology/predecessor', '16']
# ['out', 'http://dbpedia.org/property/s', '15']
# ['in', 'http://dbpedia.org/property/caption', '15']
# ['in', 'http://dbpedia.org/property/predecessor', '15']
# ['out', 'http://dbpedia.org/property/signature', '14']
# ['out', 'http://dbpedia.org/property/sname', '13']
# ['out', 'http://www.w3.org/2000/01/rdf-schema#seeAlso', '12']
# ['in', 'http://dbpedia.org/property/authors', '12']
# ['out', 'http://dbpedia.org/property/sopt', '11']
# ['out', 'http://dbpedia.org/property/restingPlace', '11']
# ['in', 'http://dbpedia.org/ontology/relative', '11']
# ['out', 'http://www.w3.org/2004/02/skos/core#exactMatch', '10']
# ['in', 'http://dbpedia.org/ontology/notableStudent', '10']
# ['out', 'http://dbpedia.org/property/wstitle', '9']
# ['out', 'http://dbpedia.org/property/volume', '9']
# ['in', 'http://dbpedia.org/property/relatives', '9']
# ['in', 'http://dbpedia.org/ontology/starring', '9']
# ['in', 'http://dbpedia.org/ontology/award', '9']
# ['in', 'http://dbpedia.org/ontology/child', '9']
# ['out', 'http://dbpedia.org/property/alt', '8']
# ['out', 'http://dbpedia.org/property/p', '8']
# ['in', 'http://dbpedia.org/ontology/dean', '8']
# ['out', 'http://dbpedia.org/property/v', '7']
# ['out', 'http://dbpedia.org/property/n', '7']
# ['out', 'http://dbpedia.org/property/year', '7']
# ['out', 'http://dbpedia.org/ontology/viafId', '7']
# ['out', 'http://dbpedia.org/property/honorificSuffix', '7']
# ['out', 'http://dbpedia.org/property/b', '7']
# ['out', 'http://dbpedia.org/property/wikt', '7']
# ['in', 'http://dbpedia.org/ontology/parent', '7']
# ['in', 'http://dbpedia.org/property/founders', '7']
# ['in', 'http://dbpedia.org/property/dean', '7']
# ['out', 'http://dbpedia.org/property/image', '6']
# ['out', 'http://dbpedia.org/property/viaf', '6']
# ['out', 'http://dbpedia.org/property/by', '6']
# ['out', 'http://dbpedia.org/property/text', '6']
# ['out', 'http://dbpedia.org/property/species', '6']
# ['out', 'http://dbpedia.org/property/c', '6']
# ['out', 'http://dbpedia.org/property/child', '6']
# ['in', 'http://www.w3.org/2000/01/rdf-schema#seeAlso', '6']
# ['in', 'http://dbpedia.org/ontology/academicAdvisor', '6']
# ['in', 'http://dbpedia.org/property/source', '6']
# ['in', 'http://dbpedia.org/property/parents', '6']
# ['in', 'http://dbpedia.org/property/head', '6']
# ['out', 'http://dbpedia.org/property/about', '5']
# ['out', 'http://dbpedia.org/property/d', '5']
# ['out', 'http://dbpedia.org/property/voy', '5']
# ['out', 'http://dbpedia.org/property/reason', '5']
# ['out', 'http://dbpedia.org/property/page', '5']
# ['in', 'http://dbpedia.org/property/aux', '5']
# ['in', 'http://dbpedia.org/property/children', '5']
# ['in', 'http://dbpedia.org/ontology/director', '5']
# ['in', 'http://dbpedia.org/property/editors', '5']
# ['in', 'http://dbpedia.org/property/director', '5']
# ['in', 'http://dbpedia.org/ontology/head', '5']
# ['out', 'http://dbpedia.org/ontology/lccnId', '4']
# ['out', 'http://dbpedia.org/property/q', '4']
# ['out', 'http://dbpedia.org/property/align', '4']
# ['out', 'http://dbpedia.org/property/lccn', '4']
# ['out', 'http://dbpedia.org/property/commons', '4']
# ['out', 'http://dbpedia.org/property/birth', '4']
# ['out', 'http://dbpedia.org/property/death', '4']
# ['out', 'http://dbpedia.org/ontology/country', '4']
# ['out', 'http://dbpedia.org/property/width', '4']
# ['in', 'http://dbpedia.org/property/writer', '4']
# ['in', 'http://dbpedia.org/property/schoolTradition', '4']
# ['in', 'http://dbpedia.org/ontology/relation', '4']
# ['in', 'http://dbpedia.org/property/discoverer', '4']
# ['in', 'http://dbpedia.org/property/sign', '4']
# ['in', 'http://dbpedia.org/property/contributions', '4']
# ['in', 'http://dbpedia.org/property/leader', '4']
# ['out', 'http://dbpedia.org/ontology/imdbId', '3']
# ['out', 'http://dbpedia.org/property/discipline', '3']
# ['out', 'http://dbpedia.org/property/content', '3']
# ['out', 'http://dbpedia.org/property/superseding', '3']
# ['out', 'http://dbpedia.org/property/pages', '3']
# ['out', 'http://dbpedia.org/property/description', '3']
# ['out', 'http://dbpedia.org/property/source', '3']
# ['out', 'http://dbpedia.org/property/subDiscipline', '3']
# ['out', 'http://dbpedia.org/property/t', '3']
# ['in', 'http://dbpedia.org/property/president', '3']
# ['in', 'http://dbpedia.org/ontology/president', '3']
# ['in', 'http://dbpedia.org/ontology/writer', '3']
# ['in', 'http://dbpedia.org/ontology/leader', '3']
# ['out', 'http://dbpedia.org/property/mw', '2']
# ['out', 'http://dbpedia.org/ontology/individualisedGnd', '2']
# ['out', 'http://dbpedia.org/property/video', '2']
# ['out', 'http://dbpedia.org/property/office', '2']
# ['out', 'http://dbpedia.org/property/author', '2']
# ['out', 'http://dbpedia.org/property/sign', '2']
# ['out', 'http://dbpedia.org/property/termStart', '2']
# ['out', 'http://dbpedia.org/property/m', '2']
# ['out', 'http://dbpedia.org/property/predecessor', '2']
# ['out', 'http://dbpedia.org/property/first', '2']
# ['out', 'http://dbpedia.org/property/gnd', '2']
# ['in', 'http://dbpedia.org/ontology/nobelLaureates', '2']
# ['in', 'http://dbpedia.org/property/chairman', '2']
# ['in', 'http://dbpedia.org/property/partner', '2']
# ['in', 'http://dbpedia.org/property/nobelLaureates', '2']
# ['in', 'http://dbpedia.org/property/with', '2']
# ['in', 'http://dbpedia.org/property/leader3Name', '2']
# ['in', 'http://dbpedia.org/property/relations', '2']
# ['in', 'http://dbpedia.org/ontology/movement', '2']
# ['in', 'http://dbpedia.org/property/academicStaff', '2']
# ['in', 'http://dbpedia.org/ontology/chairman', '2']
# ['in', 'http://dbpedia.org/ontology/partner', '2']
# ['in', 'http://dbpedia.org/property/leader1Name', '2']
# ['in', 'http://dbpedia.org/property/producer', '2']
# ['in', 'http://dbpedia.org/property/publisher', '2']
# ['in', 'http://dbpedia.org/ontology/alongside', '2']
# ['out', 'http://dbpedia.org/property/dissolved', '1']
# ['out', 'http://dbpedia.org/property/headquarters', '1']
# ['out', 'http://dbpedia.org/property/preceding', '1']
# ['out', 'http://dbpedia.org/property/yearsActive', '1']
# ['out', 'http://dbpedia.org/ontology/birthName', '1']
# ['out', 'http://dbpedia.org/property/revision', '1']
# ['out', 'http://dbpedia.org/ontology/activeYearsStartYear', '1']
# ['out', 'http://dbpedia.org/ontology/wikiPageRedirects', '1']
# ['out', 'http://dbpedia.org/property/quote', '1']
# ['out', 'http://dbpedia.org/ontology/activeYearsEndYear', '1']
# ['out', 'http://dbpedia.org/property/expanded', '1']
# ['out', 'http://dbpedia.org/property/sourcepath', '1']
# ['out', 'http://dbpedia.org/property/j', '1']
# ['out', 'http://dbpedia.org/property/colwidth', '1']
# ['out', 'http://dbpedia.org/property/with', '1']
# ['out', 'http://dbpedia.org/ontology/alias', '1']
# ['out', 'http://dbpedia.org/property/y', '1']
# ['out', 'http://dbpedia.org/property/dSearch', '1']
# ['out', 'http://dbpedia.org/property/parentAgency', '1']
# ['out', 'http://dbpedia.org/property/children', '1']
# ['out', 'http://dbpedia.org/property/education', '1']
# ['out', 'http://dbpedia.org/ontology/birthYear', '1']
# ['out', 'http://dbpedia.org/property/hangul', '1']
# ['out', 'http://dbpedia.org/property/termEnd', '1']
# ['out', 'http://dbpedia.org/property/free', '1']
# ['out', 'http://dbpedia.org/property/occupation', '1']
# ['out', 'http://dbpedia.org/ontology/education', '1']
# ['out', 'http://dbpedia.org/property/hanja', '1']
# ['out', 'http://dbpedia.org/property/successor', '1']
# ['out', 'http://dbpedia.org/property/spouses', '1']
# ['out', 'http://dbpedia.org/property/last', '1']
# ['out', 'http://dbpedia.org/property/formed', '1']
# ['out', 'http://dbpedia.org/property/chief1Name', '1']
# ['out', 'http://dbpedia.org/property/isbn', '1']
# ['out', 'http://dbpedia.org/property/chief2Name', '1']
# ['out', 'http://dbpedia.org/property/otherNames', '1']
# ['out', 'http://dbpedia.org/property/typ', '1']
# ['out', 'http://dbpedia.org/property/mr', '1']
# ['out', 'http://dbpedia.org/property/tablewidth', '1']
# ['out', 'http://dbpedia.org/property/module', '1']
# ['out', 'http://dbpedia.org/property/small', '1']
# ['out', 'http://dbpedia.org/property/talk', '1']
# ['out', 'http://dbpedia.org/property/float', '1']
# ['out', 'http://dbpedia.org/ontology/child', '1']
# ['out', 'http://dbpedia.org/ontology/occupation', '1']
# ['out', 'http://dbpedia.org/property/sp', '1']
# ['out', 'http://dbpedia.org/property/memorials', '1']
# ['out', 'http://dbpedia.org/property/sSearch', '1']
# ['out', 'http://dbpedia.org/property/l', '1']
# ['out', 'http://dbpedia.org/property/topic', '1']
# ['out', 'http://dbpedia.org/property/color', '1']
# ['out', 'http://dbpedia.org/property/rr', '1']
# ['out', 'http://dbpedia.org/property/employer', '1']
# ['out', 'http://dbpedia.org/ontology/deathYear', '1']
# ['out', 'http://dbpedia.org/ontology/employer', '1']
# ['out', 'http://dbpedia.org/property/footer', '1']
# ['in', 'http://dbpedia.org/property/preceding', '1']
# ['in', 'http://dbpedia.org/property/boardOfDirectors', '1']
# ['in', 'http://dbpedia.org/ontology/viceChancellor', '1']
# ['in', 'http://dbpedia.org/property/viceChancellor', '1']
# ['in', 'http://dbpedia.org/ontology/knownFor', '1']
# ['in', 'http://dbpedia.org/ontology/binomialAuthority', '1']
# ['in', 'http://dbpedia.org/property/1namedata', '1']
# ['in', 'http://dbpedia.org/property/connectedMembers', '1']
# ['in', 'http://dbpedia.org/property/minister', '1']
# ['in', 'http://dbpedia.org/property/family', '1']
# ['in', 'http://dbpedia.org/property/cinematography', '1']
# ['in', 'http://dbpedia.org/property/free', '1']
# ['in', 'http://dbpedia.org/property/holder', '1']
# ['in', 'http://dbpedia.org/property/namedAfter', '1']
# ['in', 'http://dbpedia.org/property/notable', '1']
# ['in', 'http://dbpedia.org/property/father', '1']
# ['in', 'http://dbpedia.org/property/officeholder', '1']
# ['in', 'http://dbpedia.org/property/superseding', '1']
# ['in', 'http://dbpedia.org/property/previousEditor', '1']
# ['in', 'http://dbpedia.org/property/vpName', '1']
# ['in', 'http://dbpedia.org/ontology/producer', '1']
# ['in', 'http://dbpedia.org/property/notes', '1']
# ['in', 'http://dbpedia.org/property/host', '1']
# ['in', 'http://dbpedia.org/property/chief2Name', '1']
# ['in', 'http://dbpedia.org/property/principal', '1']
# ['in', 'http://dbpedia.org/property/coverArtist', '1']
# ['in', 'http://dbpedia.org/property/mother', '1']
# ['in', 'http://dbpedia.org/ontology/cinematography', '1']
# ['in', 'http://dbpedia.org/ontology/previousEditor', '1']
# ['in', 'http://dbpedia.org/property/motm', '1']
# ['in', 'http://dbpedia.org/property/incumbent', '1']
# ['in', 'http://dbpedia.org/property/movement', '1']
# ['in', 'http://dbpedia.org/ontology/principal', '1']

# %%
len(r)
# Out:
# 311

# %% [markdown]
# ### Résultats
#
# Requêtes effectuées le 21 février 2021
#
# #### Economist (ontology) : https://dbpedia.org/ontology/Economist
# <code>
# ['in', 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type', '1570']
# ['out', 'http://www.w3.org/2000/01/rdf-schema#label', '18']
# ['out', 'http://www.w3.org/2000/01/rdf-schema#comment', '6']
# ['out', 'http://www.w3.org/2002/07/owl#equivalentClass', '2']
# ['out', 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type', '2']
# ['out', 'http://www.w3.org/ns/prov#wasDerivedFrom', '2']
# ['out', 'http://www.w3.org/2000/01/rdf-schema#subClassOf', '2']
# ['out', 'http://www.w3.org/2007/05/powder-s#describedby', '1']
# ['in', 'http://open.vocab.org/terms/defines', '1']
# ['out', 'http://www.w3.org/2000/01/rdf-schema#isDefinedBy', '1']
# ['in', 'http://open.vocab.org/terms/describes', '1']
#     </code>
#
#
# #### Economist (resource): https://dbpedia.org/resource/Economist
#
# <code>
# ['in', 'http://dbpedia.org/ontology/wikiPageWikiLink', '3667']
# ['in', 'http://dbpedia.org/ontology/occupation', '380']
# ['in', 'http://dbpedia.org/ontology/profession', '356']
# ['in', 'http://dbpedia.org/property/profession', '314']
# ['in', 'http://dbpedia.org/property/occupation', '248']
# ['out', 'http://dbpedia.org/ontology/wikiPageWikiLink', '91']
# ['out', 'http://www.w3.org/2002/07/owl#sameAs', '61']
# ['in', 'http://dbpedia.org/ontology/academicDiscipline', '23']
# ['out', 'http://www.w3.org/2000/01/rdf-schema#label', '21']
# ['out', 'http://www.w3.org/2000/01/rdf-schema#comment', '20']
# ['out', 'http://dbpedia.org/ontology/abstract', '20']
# ['in', 'http://dbpedia.org/property/field', '19']
# ['out', 'http://dbpedia.org/property/wikiPageUsesTemplate', '15']
# ['in', 'http://dbpedia.org/ontology/field', '9']
# ['in', 'http://dbpedia.org/property/fields', '8']
# ['in', 'http://dbpedia.org/ontology/knownFor', '5']
# ['in', 'http://dbpedia.org/property/discipline', '4']
# ['in', 'http://dbpedia.org/ontology/wikiPageRedirects', '3']
# ['out', 'http://purl.org/dc/terms/subject', '3']
# ['out', 'http://dbpedia.org/ontology/wikiPageExternalLink', '2']
# ['in', 'http://dbpedia.org/property/schoolTradition', '2']
# ['out', 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type', '2']
# ['in', 'http://dbpedia.org/ontology/education', '2']
# ['out', 'http://dbpedia.org/ontology/wikiPageRevisionID', '1']
# ['out', 'http://dbpedia.org/ontology/thumbnail', '1']
# ['out', 'http://dbpedia.org/ontology/wikiPageID', '1']
# ['out', 'http://purl.org/dc/terms/isPartOf', '1']
# ['in', 'http://dbpedia.org/property/office', '1']
# ['in', 'http://dbpedia.org/ontology/institution', '1']
# ['in', 'http://dbpedia.org/property/knownFor', '1']
# ['in', 'http://dbpedia.org/property/contributions', '1']
# ['out', 'http://xmlns.com/foaf/0.1/isPrimaryTopicOf', '1']
# ['in', 'http://dbpedia.org/property/otheroccupation', '1']
# ['in', 'http://dbpedia.org/ontology/influencedBy', '1']
# ['in', 'http://xmlns.com/foaf/0.1/primaryTopic', '1']
# ['in', 'http://dbpedia.org/ontology/wikiPageDisambiguates', '1']
# ['in', 'http://dbpedia.org/property/laterwork', '1']
# ['in', 'http://dbpedia.org/ontology/discipline', '1']
# ['out', 'http://www.w3.org/ns/prov#wasDerivedFrom', '1']
# ['in', 'http://dbpedia.org/property/education', '1']
# ['out', 'http://www.w3.org/2000/01/rdf-schema#seeAlso', '1']
# ['out', 'http://xmlns.com/foaf/0.1/depiction', '1']
# ['out', 'http://dbpedia.org/ontology/wikiPageLength', '1']
# ['out', 'http://www.w3.org/2004/02/skos/core#closeMatch', '1']
#
# </code>
#
#
#
#
# #### Economics (https://dbpedia.org/resource/Economics)
#
#
# <code>
# ['in', 'http://dbpedia.org/ontology/wikiPageWikiLink', '8925']
# ['out', 'http://dbpedia.org/ontology/wikiPageWikiLink', '507']
# ['in', 'http://dbpedia.org/ontology/academicDiscipline', '356']
# ['in', 'http://dbpedia.org/property/field', '230']
# ['in', 'http://dbpedia.org/property/discipline', '175']
# ['in', 'http://dbpedia.org/ontology/field', '128']
# ['out', 'http://www.w3.org/2002/07/owl#sameAs', '115']
# ['in', 'http://dbpedia.org/property/fields', '86']
# ['in', 'http://dbpedia.org/property/subject', '67']
# ['in', 'http://dbpedia.org/ontology/nonFictionSubject', '61']
# ['in', 'http://dbpedia.org/ontology/education', '53']
# ['out', 'http://dbpedia.org/property/wikiPageUsesTemplate', '44']
# ['in', 'http://dbpedia.org/ontology/wikiPageRedirects', '43']
# ['in', 'http://dbpedia.org/property/genre', '30']
# ['in', 'http://dbpedia.org/ontology/mainInterest', '29']
# ['in', 'http://dbpedia.org/property/mainInterests', '29']
# ['in', 'http://dbpedia.org/ontology/literaryGenre', '26']
# ['out', 'http://dbpedia.org/ontology/wikiPageExternalLink', '25']
# ['out', 'http://www.w3.org/2000/01/rdf-schema#comment', '22']
# ['out', 'http://dbpedia.org/ontology/abstract', '22']
# ['out', 'http://www.w3.org/2000/01/rdf-schema#label', '22']
# ['in', 'http://dbpedia.org/ontology/knownFor', '21']
# ['in', 'http://dbpedia.org/ontology/almaMater', '18']
# ['in', 'http://dbpedia.org/ontology/occupation', '17']
# ['in', 'http://dbpedia.org/property/education', '16']
# ['in', 'http://dbpedia.org/property/skills', '16']
# ['in', 'http://dbpedia.org/ontology/profession', '16']
# ['in', 'http://dbpedia.org/ontology/genre', '14']
# ['in', 'http://purl.org/dc/elements/1.1/subject', '12']
# ['in', 'http://dbpedia.org/property/profession', '11']
# ['in', 'http://dbpedia.org/property/knownFor', '10']
# ['in', 'http://dbpedia.org/property/category', '7']
# ['in', 'http://dbpedia.org/property/focus', '5']
# ['in', 'http://dbpedia.org/ontology/type', '5']
# ['in', 'http://dbpedia.org/property/industry', '5']
# ['in', 'http://www.w3.org/2000/01/rdf-schema#seeAlso', '4']
# ['in', 'http://dbpedia.org/property/type', '4']
# ['in', 'http://dbpedia.org/property/occupation', '3']
# ['in', 'http://dbpedia.org/property/researchField', '3']
# ['in', 'http://dbpedia.org/ontology/industry', '3']
# ['in', 'http://dbpedia.org/property/almaMater', '3']
# ['out', 'http://www.w3.org/2000/01/rdf-schema#seeAlso', '3']
# ['in', 'http://dbpedia.org/property/subjects', '3']
# ['out', 'http://www.w3.org/2004/02/skos/core#closeMatch', '3']
# ['in', 'http://dbpedia.org/property/schoolTradition', '2']
# ['in', 'http://dbpedia.org/ontology/award', '2']
# ['out', 'http://purl.org/dc/terms/subject', '2']
# ['in', 'http://dbpedia.org/ontology/wikiPageDisambiguates', '2']
# ['out', 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type', '2']
# ['in', 'http://www.w3.org/2002/07/owl#differentFrom', '2']
# ['out', 'http://dbpedia.org/ontology/wikiPageRevisionID', '1']
# ['out', 'http://dbpedia.org/ontology/thumbnail', '1']
# ['out', 'http://dbpedia.org/ontology/wikiPageID', '1']
# ['out', 'http://purl.org/dc/terms/isPartOf', '1']
# ['in', 'http://dbpedia.org/property/faculty', '1']
# ['in', 'http://dbpedia.org/property/group', '1']
# ['in', 'http://dbpedia.org/ontology/picture', '1']
# ['in', 'http://dbpedia.org/property/skillsTested', '1']
# ['out', 'http://xmlns.com/foaf/0.1/isPrimaryTopicOf', '1']
# ['out', 'http://dbpedia.org/property/onlinebooks', '1']
# ['in', 'http://dbpedia.org/property/scope', '1']
# ['in', 'http://dbpedia.org/property/topics', '1']
# ['out', 'http://dbpedia.org/property/label', '1']
# ['in', 'http://xmlns.com/foaf/0.1/primaryTopic', '1']
# ['in', 'http://dbpedia.org/property/purpose', '1']
# ['in', 'http://dbpedia.org/property/subDiscipline', '1']
# ['out', 'http://dbpedia.org/property/by', '1']
# ['out', 'http://www.w3.org/ns/prov#wasDerivedFrom', '1']
# ['in', 'http://dbpedia.org/property/activitySector', '1']
# ['in', 'http://dbpedia.org/property/classesOffered', '1']
# ['out', 'http://dbpedia.org/property/about', '1']
# ['out', 'http://xmlns.com/foaf/0.1/depiction', '1']
# ['out', 'http://dbpedia.org/ontology/wikiPageLength', '1']
# ['in', 'http://dbpedia.org/property/vp', '1']
# ['out', 'http://dbpedia.org/property/others', '1']
# ['in', 'http://dbpedia.org/ontology/service', '1']
# </code>
